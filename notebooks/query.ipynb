# %%
import os

import dotenv
from tiled.client import from_uri
from tiled.queries import Contains, In, Key

dotenv.load_dotenv()
c = from_uri("https://tiled.nsls2.bnl.gov", api_key=os.getenv('TILED_API_KEY'))
smi = c['smi']

# %%
scans = c["smi"]["raw"].search(Key("num_points") > 9).search(Contains("detectors", "pil900KW")).values().tail(10)

# %%
for scan in scans:
    print(f"{scan.metadata['start']['uid']}  {scan.metadata['stop']['num_events']}")
# Out:
# 2d0b6405-7ac2-4f47-b879-abd4c408b269  {'baseline': 2, 'primary': 600}
# 9069b091-a978-4211-b034-33f28e6fda7d  {'baseline': 2, 'primary': 600}
# 0b3768a3-256e-417b-bcc4-ba937915c022  {'baseline': 2, 'primary': 600}
# 9a5ed678-bf01-4e16-a2a0-c78649f150be  {'baseline': 2, 'primary': 600}
# 01a8c2ca-f441-4883-ad6f-fce2f804bfea  {'baseline': 2, 'primary': 600}
# c21d472b-4241-4f48-8d62-a0b56e1d471d  {'baseline': 2, 'primary': 600}
# 436f6bfa-6841-4ddf-bb2b-1e32f4ca0ac5  {'baseline': 2, 'primary': 10}
# 9c123d4f-8d2e-4369-bad6-d49caf60d672  {'baseline': 2, 'primary': 10}
# c408e205-7801-483b-bdb6-76b5bbadf529  {'baseline': 2, 'primary': 10}
# c834dd6a-91a8-4727-b534-f45ed6acf191  {'baseline': 2, 'primary': 8}

# %%
list(scan.documents())
# Out:
# [('start',
#   Start({'SAF_number': 315130,
#  'SAXS_setup': {'beam_centre': [467, 798],
#                 'bs': 'rod',
#                 'energy': 16100,
#                 'sdd': 3000},
#  'beamline_attenuators': {},
#  'beamline_beamsize': 'low_divergence',
#  'beamline_name': 'SMI',
#  'beamline_sample_environment': 'in-air',
#  'cycle': '2024_3',
#  'detectors': ['pil900KW'],
#  'facility': 'NSLS-II',
#  'hints': {'dimensions': [[['time'], 'primary']]},
#  'main_proposer': 'Wasik',
#  'num_intervals': 99,
#  'num_points': 100,
#  'optional_comments': '',
#  'path': '/nsls2/data/smi/legacy/results/data/2024_3/316942_Wasik_02',
#  'plan_args': {'delay': None,
#                'detectors': ["Pilatus(prefix='XF:12IDC-ES:2{Det:900KW}', "
#                              "name='pil900KW', read_attrs=['cam', "
#                              "'cam.file_number', 'tiff', 'stats1', "
#                              "'stats1.total'], configuration_attrs=['cam', "
#                              "'cam.acquire_period', 'cam.acquire_time', "
#                              "'cam.image_mode', 'cam.manufacturer', "
#                              "'cam.model', 'cam.num_exposures', "
#                              "'cam.num_images', 'cam.trigger_mode', 'tiff', "
#                              "'stats1', 'stats1.bgd_width', "
#                              "'stats1.centroid_threshold', "
#                              "'stats1.compute_centroid', "
#                              "'stats1.compute_histogram', "
#                              "'stats1.compute_profiles', "
#                              "'stats1.compute_statistics', 'stats1.hist_max', "
#                              "'stats1.hist_min', 'stats1.hist_size', "
#                              "'stats1.profile_cursor', 'stats1.profile_size', "
#                              "'stats1.ts_num_points'])"],
#                'num': 100},
#  'plan_name': 'count',
#  'plan_type': 'generator',
#  'proposal_id': '316942_Wasik_02',
#  'proposal_number': '316942',
#  'sample_name': 'test',
#  'scan_id': 866685,
#  'time': 1731627147.0759113,
#  'uid': 'c834dd6a-91a8-4727-b534-f45ed6acf191',
#  'user_name': 'test'})),
#  ('descriptor',
#   Descriptor({'configuration': {'detector_saxs_pos': {'data': {'detector_saxs_pos_x_user_setpoint': -2.77,
#                                                   'detector_saxs_pos_y': -20.0003,
#                                                   'detector_saxs_pos_y_user_setpoint': -20.0,
#                                                   'detector_saxs_pos_z': 3000.000512},
#                                          'data_keys': {'detector_saxs_pos_x_user_setpoint': {'dtype': 'number',
#                                                                                              'lower_ctrl_limit': -85.6,
#                                                                                              'precision': 5,
#                                                                                              'shape': [],
#                                                                                              'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:X}Mtr.VAL',
#                                                                                              'units': 'mm',
#                                                                                              'upper_ctrl_limit': 78.9},
#                                                        'detector_saxs_pos_y': {'dtype': 'number',
#                                                                                'lower_ctrl_limit': -61.5,
#                                                                                'precision': 5,
#                                                                                'shape': [],
#                                                                                'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Y}Mtr.RBV',
#                                                                                'units': 'mm',
#                                                                                'upper_ctrl_limit': 26.7},
#                                                        'detector_saxs_pos_y_user_setpoint': {'dtype': 'number',
#                                                                                              'lower_ctrl_limit': -61.5,
#                                                                                              'precision': 5,
#                                                                                              'shape': [],
#                                                                                              'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Y}Mtr.VAL',
#                                                                                              'units': 'mm',
#                                                                                              'upper_ctrl_limit': 26.7},
#                                                        'detector_saxs_pos_z': {'dtype': 'number',
#                                                                                'lower_ctrl_limit': 1588.699792,
#                                                                                'precision': 5,
#                                                                                'shape': [],
#                                                                                'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Z}Mtr.RBV',
#                                                                                'units': 'mm',
#                                                                                'upper_ctrl_limit': 9288.0}},
#                                          'timestamps': {'detector_saxs_pos_x_user_setpoint': 1731515584.466179,
#                                                         'detector_saxs_pos_y': 1731627146.190322,
#                                                         'detector_saxs_pos_y_user_setpoint': 1731515576.068849,
#                                                         'detector_saxs_pos_z': 1731596488.503149}},
#                    'energy': {'data': {'energy_bragg_acceleration': 0.5,
#                                        'energy_bragg_motor_egu': 'deg',
#                                        'energy_bragg_user_offset': 1.423,
#                                        'energy_bragg_user_offset_dir': 0,
#                                        'energy_bragg_velocity': 5.0,
#                                        'energy_enabledcmgap': True,
#                                        'energy_enableivu': True,
#                                        'energy_target_harmonic': 21},
#                               'data_keys': {'energy_bragg_acceleration': {'dtype': 'number',
#                                                                           'lower_ctrl_limit': -1e+300,
#                                                                           'precision': 5,
#                                                                           'shape': [],
#                                                                           'source': 'PV:XF:12ID:m65.ACCL',
#                                                                           'units': 'sec',
#                                                                           'upper_ctrl_limit': 1e+300},
#                                             'energy_bragg_motor_egu': {'dtype': 'string',
#                                                                        'lower_ctrl_limit': None,
#                                                                        'shape': [],
#                                                                        'source': 'PV:XF:12ID:m65.EGU',
#                                                                        'units': None,
#                                                                        'upper_ctrl_limit': None},
#                                             'energy_bragg_user_offset': {'dtype': 'number',
#                                                                          'lower_ctrl_limit': -1e+300,
#                                                                          'precision': 5,
#                                                                          'shape': [],
#                                                                          'source': 'PV:XF:12ID:m65.OFF',
#                                                                          'units': 'deg',
#                                                                          'upper_ctrl_limit': 1e+300},
#                                             'energy_bragg_user_offset_dir': {'dtype': 'integer',
#                                                                              'enum_strs': ['Pos',
#                                                                                            'Neg'],
#                                                                              'lower_ctrl_limit': None,
#                                                                              'shape': [],
#                                                                              'source': 'PV:XF:12ID:m65.DIR',
#                                                                              'units': None,
#                                                                              'upper_ctrl_limit': None},
#                                             'energy_bragg_velocity': {'dtype': 'number',
#                                                                       'lower_ctrl_limit': 0.0,
#                                                                       'precision': 5,
#                                                                       'shape': [],
#                                                                       'source': 'PV:XF:12ID:m65.VELO',
#                                                                       'units': 'deg/sec',
#                                                                       'upper_ctrl_limit': 5.0},
#                                             'energy_enabledcmgap': {'dtype': 'integer',
#                                                                     'shape': [],
#                                                                     'source': 'SIM:energy_enabledcmgap'},
#                                             'energy_enableivu': {'dtype': 'integer',
#                                                                  'shape': [],
#                                                                  'source': 'SIM:energy_enableivu'},
#                                             'energy_target_harmonic': {'dtype': 'integer',
#                                                                        'shape': [],
#                                                                        'source': 'SIM:energy_target_harmonic'}},
#                               'timestamps': {'energy_bragg_acceleration': 1731515585.943449,
#                                              'energy_bragg_motor_egu': 1731515586.960641,
#                                              'energy_bragg_user_offset': 1731515585.943449,
#                                              'energy_bragg_user_offset_dir': 1731515585.943449,
#                                              'energy_bragg_velocity': 1731515585.943449,
#                                              'energy_enabledcmgap': 1731515586.5007393,
#                                              'energy_enableivu': 1731515586.5007288,
#                                              'energy_target_harmonic': 1731515586.500747}},
#                    'piezo': {'data': {'piezo_ch': 7.350293,
#                                       'piezo_ch_user_setpoint': 7.6000000000000005,
#                                       'piezo_th': 1.037593,
#                                       'piezo_x_user_setpoint': 0.0,
#                                       'piezo_y': 25.995,
#                                       'piezo_y_user_setpoint': 0.0,
#                                       'piezo_z': -2394.743},
#                              'data_keys': {'piezo_ch': {'dtype': 'number',
#                                                         'lower_ctrl_limit': -8.0,
#                                                         'precision': 6,
#                                                         'shape': [],
#                                                         'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:4}Mtr.RBV',
#                                                         'units': 'deg',
#                                                         'upper_ctrl_limit': 8.0},
#                                            'piezo_ch_user_setpoint': {'dtype': 'number',
#                                                                       'lower_ctrl_limit': -8.0,
#                                                                       'precision': 6,
#                                                                       'shape': [],
#                                                                       'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:4}Mtr.VAL',
#                                                                       'units': 'deg',
#                                                                       'upper_ctrl_limit': 8.0},
#                                            'piezo_th': {'dtype': 'number',
#                                                         'lower_ctrl_limit': -6.4,
#                                                         'precision': 6,
#                                                         'shape': [],
#                                                         'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:1}Mtr.RBV',
#                                                         'units': 'deg',
#                                                         'upper_ctrl_limit': 6.4},
#                                            'piezo_x_user_setpoint': {'dtype': 'number',
#                                                                      'lower_ctrl_limit': -60000.0,
#                                                                      'precision': 3,
#                                                                      'shape': [],
#                                                                      'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:0}Mtr.VAL',
#                                                                      'units': 'um',
#                                                                      'upper_ctrl_limit': 70000.0},
#                                            'piezo_y': {'dtype': 'number',
#                                                        'lower_ctrl_limit': -10950.0,
#                                                        'precision': 3,
#                                                        'shape': [],
#                                                        'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:3}Mtr.RBV',
#                                                        'units': 'um',
#                                                        'upper_ctrl_limit': 11000.0},
#                                            'piezo_y_user_setpoint': {'dtype': 'number',
#                                                                      'lower_ctrl_limit': -10950.0,
#                                                                      'precision': 3,
#                                                                      'shape': [],
#                                                                      'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:3}Mtr.VAL',
#                                                                      'units': 'um',
#                                                                      'upper_ctrl_limit': 11000.0},
#                                            'piezo_z': {'dtype': 'number',
#                                                        'lower_ctrl_limit': -36110.0,
#                                                        'precision': 3,
#                                                        'shape': [],
#                                                        'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:6}Mtr.RBV',
#                                                        'units': 'um',
#                                                        'upper_ctrl_limit': 24210.0}},
#                              'timestamps': {'piezo_ch': 1731627146.30515,
#                                             'piezo_ch_user_setpoint': 1731515585.064198,
#                                             'piezo_th': 1731627146.280529,
#                                             'piezo_x_user_setpoint': 1731602707.626181,
#                                             'piezo_y': 1731627146.294548,
#                                             'piezo_y_user_setpoint': 1731599955.169367,
#                                             'piezo_z': 1731627143.107971}},
#                    'prs': {'data': {'prs': -3.0, 'prs_user_setpoint': -3.0},
#                            'data_keys': {'prs': {'dtype': 'number',
#                                                  'lower_ctrl_limit': -269.0,
#                                                  'precision': 5,
#                                                  'shape': [],
#                                                  'source': 'PV:XF:12IDC-OP:2{HEX:PRS-Ax:Rot}Mtr.RBV',
#                                                  'units': 'deg',
#                                                  'upper_ctrl_limit': 181.0},
#                                          'prs_user_setpoint': {'dtype': 'number',
#                                                                'lower_ctrl_limit': -269.0,
#                                                                'precision': 5,
#                                                                'shape': [],
#                                                                'source': 'PV:XF:12IDC-OP:2{HEX:PRS-Ax:Rot}Mtr.VAL',
#                                                                'units': 'deg',
#                                                                'upper_ctrl_limit': 181.0}},
#                            'timestamps': {'prs': 1731624147.52607,
#                                           'prs_user_setpoint': 1731515585.142099}},
#                    'ring_current': {'data': {'ring_current': 400.17440319156856},
#                                     'data_keys': {'ring_current': {'dtype': 'number',
#                                                                    'lower_ctrl_limit': 0.0,
#                                                                    'precision': 3,
#                                                                    'shape': [],
#                                                                    'source': 'PV:SR:C03-BI{DCCT:1}I:Real-I',
#                                                                    'units': 'mA',
#                                                                    'upper_ctrl_limit': 0.0}},
#                                     'timestamps': {'ring_current': 1731627146.838292}},
#                    'stage': {'data': {'stage_ch': -0.001,
#                                       'stage_ch_user_setpoint': -0.001,
#                                       'stage_ph': -5.0,
#                                       'stage_th': 0.0,
#                                       'stage_x_user_setpoint': 30.5,
#                                       'stage_y': 2.2,
#                                       'stage_y_user_setpoint': 2.2,
#                                       'stage_z': 4.995},
#                              'data_keys': {'stage_ch': {'dtype': 'number',
#                                                         'lower_ctrl_limit': -90.0,
#                                                         'precision': 5,
#                                                         'shape': [],
#                                                         'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:chi}Mtr.RBV',
#                                                         'units': 'deg',
#                                                         'upper_ctrl_limit': 90.0},
#                                            'stage_ch_user_setpoint': {'dtype': 'number',
#                                                                       'lower_ctrl_limit': -90.0,
#                                                                       'precision': 5,
#                                                                       'shape': [],
#                                                                       'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:chi}Mtr.VAL',
#                                                                       'units': 'deg',
#                                                                       'upper_ctrl_limit': 90.0},
#                                            'stage_ph': {'dtype': 'number',
#                                                         'lower_ctrl_limit': -180.0,
#                                                         'precision': 5,
#                                                         'shape': [],
#                                                         'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:phi}Mtr.RBV',
#                                                         'units': 'deg',
#                                                         'upper_ctrl_limit': 90.0},
#                                            'stage_th': {'dtype': 'number',
#                                                         'lower_ctrl_limit': -90.0,
#                                                         'precision': 5,
#                                                         'shape': [],
#                                                         'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:theta}Mtr.RBV',
#                                                         'units': 'deg',
#                                                         'upper_ctrl_limit': 90.0},
#                                            'stage_x_user_setpoint': {'dtype': 'number',
#                                                                      'lower_ctrl_limit': -33.0,
#                                                                      'precision': 5,
#                                                                      'shape': [],
#                                                                      'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:X}Mtr.VAL',
#                                                                      'units': 'mm',
#                                                                      'upper_ctrl_limit': 33.0},
#                                            'stage_y': {'dtype': 'number',
#                                                        'lower_ctrl_limit': -33.0,
#                                                        'precision': 5,
#                                                        'shape': [],
#                                                        'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Y}Mtr.RBV',
#                                                        'units': 'mm',
#                                                        'upper_ctrl_limit': 33.0},
#                                            'stage_y_user_setpoint': {'dtype': 'number',
#                                                                      'lower_ctrl_limit': -33.0,
#                                                                      'precision': 5,
#                                                                      'shape': [],
#                                                                      'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Y}Mtr.VAL',
#                                                                      'units': 'mm',
#                                                                      'upper_ctrl_limit': 33.0},
#                                            'stage_z': {'dtype': 'number',
#                                                        'lower_ctrl_limit': -33.0,
#                                                        'precision': 5,
#                                                        'shape': [],
#                                                        'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Z}Mtr.RBV',
#                                                        'units': 'mm',
#                                                        'upper_ctrl_limit': 33.0}},
#                              'timestamps': {'stage_ch': 1731626869.071743,
#                                             'stage_ch_user_setpoint': 1731626872.804338,
#                                             'stage_ph': 1731626369.518718,
#                                             'stage_th': 1731626703.377803,
#                                             'stage_x_user_setpoint': 1731626868.715177,
#                                             'stage_y': 1731626290.392629,
#                                             'stage_y_user_setpoint': 1731626872.795409,
#                                             'stage_z': 1731626703.375609}}},
#  'data_keys': {'detector_saxs_pos_x': {'dtype': 'number',
#                                        'lower_ctrl_limit': -85.6,
#                                        'object_name': 'detector_saxs_pos',
#                                        'precision': 5,
#                                        'shape': [],
#                                        'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:X}Mtr.RBV',
#                                        'units': 'mm',
#                                        'upper_ctrl_limit': 78.9},
#                'detector_saxs_pos_x_user_setpoint': {'dtype': 'number',
#                                                      'lower_ctrl_limit': -85.6,
#                                                      'object_name': 'detector_saxs_pos',
#                                                      'precision': 5,
#                                                      'shape': [],
#                                                      'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:X}Mtr.VAL',
#                                                      'units': 'mm',
#                                                      'upper_ctrl_limit': 78.9},
#                'detector_saxs_pos_y': {'dtype': 'number',
#                                        'lower_ctrl_limit': -61.5,
#                                        'object_name': 'detector_saxs_pos',
#                                        'precision': 5,
#                                        'shape': [],
#                                        'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Y}Mtr.RBV',
#                                        'units': 'mm',
#                                        'upper_ctrl_limit': 26.7},
#                'detector_saxs_pos_y_user_setpoint': {'dtype': 'number',
#                                                      'lower_ctrl_limit': -61.5,
#                                                      'object_name': 'detector_saxs_pos',
#                                                      'precision': 5,
#                                                      'shape': [],
#                                                      'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Y}Mtr.VAL',
#                                                      'units': 'mm',
#                                                      'upper_ctrl_limit': 26.7},
#                'detector_saxs_pos_z': {'dtype': 'number',
#                                        'lower_ctrl_limit': 1588.699792,
#                                        'object_name': 'detector_saxs_pos',
#                                        'precision': 5,
#                                        'shape': [],
#                                        'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Z}Mtr.RBV',
#                                        'units': 'mm',
#                                        'upper_ctrl_limit': 9288.0},
#                'detector_saxs_pos_z_user_setpoint': {'dtype': 'number',
#                                                      'lower_ctrl_limit': 1588.699792,
#                                                      'object_name': 'detector_saxs_pos',
#                                                      'precision': 5,
#                                                      'shape': [],
#                                                      'source': 'PV:XF:12IDC-ES:2{Det:1M-Ax:Z}Mtr.VAL',
#                                                      'units': 'mm',
#                                                      'upper_ctrl_limit': 9288.0},
#                'energy_bragg': {'dtype': 'number',
#                                 'lower_ctrl_limit': -0.47699999999999987,
#                                 'object_name': 'energy',
#                                 'precision': 5,
#                                 'shape': [],
#                                 'source': 'PV:XF:12ID:m65.RBV',
#                                 'units': 'deg',
#                                 'upper_ctrl_limit': 76.223},
#                'energy_energy': {'dtype': 'number',
#                                  'lower_ctrl_limit': 0,
#                                  'object_name': 'energy',
#                                  'shape': [],
#                                  'source': 'PY:energy_energy.position',
#                                  'units': '',
#                                  'upper_ctrl_limit': 0},
#                'energy_energy_setpoint': {'dtype': 'integer',
#                                           'lower_ctrl_limit': 0,
#                                           'object_name': 'energy',
#                                           'shape': [],
#                                           'source': 'PY:energy_energy.target',
#                                           'units': '',
#                                           'upper_ctrl_limit': 0},
#                'energy_harmonic': {'dtype': 'integer',
#                                    'object_name': 'energy',
#                                    'shape': [],
#                                    'source': 'SIM:energy_harmonic'},
#                'energy_ivugap': {'dtype': 'number',
#                                  'lower_ctrl_limit': 6200.0,
#                                  'object_name': 'energy',
#                                  'precision': 2,
#                                  'shape': [],
#                                  'source': 'PV:SR:C12-ID:G1{IVU:1-Ax:Gap}-Mtr.RBV',
#                                  'units': 'um',
#                                  'upper_ctrl_limit': 25150.0},
#                'piezo_ch': {'dtype': 'number',
#                             'lower_ctrl_limit': -8.0,
#                             'object_name': 'piezo',
#                             'precision': 6,
#                             'shape': [],
#                             'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:4}Mtr.RBV',
#                             'units': 'deg',
#                             'upper_ctrl_limit': 8.0},
#                'piezo_ch_user_setpoint': {'dtype': 'number',
#                                           'lower_ctrl_limit': -8.0,
#                                           'object_name': 'piezo',
#                                           'precision': 6,
#                                           'shape': [],
#                                           'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:4}Mtr.VAL',
#                                           'units': 'deg',
#                                           'upper_ctrl_limit': 8.0},
#                'piezo_th': {'dtype': 'number',
#                             'lower_ctrl_limit': -6.4,
#                             'object_name': 'piezo',
#                             'precision': 6,
#                             'shape': [],
#                             'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:1}Mtr.RBV',
#                             'units': 'deg',
#                             'upper_ctrl_limit': 6.4},
#                'piezo_th_user_setpoint': {'dtype': 'number',
#                                           'lower_ctrl_limit': -6.4,
#                                           'object_name': 'piezo',
#                                           'precision': 6,
#                                           'shape': [],
#                                           'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:1}Mtr.VAL',
#                                           'units': 'deg',
#                                           'upper_ctrl_limit': 6.4},
#                'piezo_x': {'dtype': 'number',
#                            'lower_ctrl_limit': -60000.0,
#                            'object_name': 'piezo',
#                            'precision': 3,
#                            'shape': [],
#                            'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:0}Mtr.RBV',
#                            'units': 'um',
#                            'upper_ctrl_limit': 70000.0},
#                'piezo_x_user_setpoint': {'dtype': 'number',
#                                          'lower_ctrl_limit': -60000.0,
#                                          'object_name': 'piezo',
#                                          'precision': 3,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:0}Mtr.VAL',
#                                          'units': 'um',
#                                          'upper_ctrl_limit': 70000.0},
#                'piezo_y': {'dtype': 'number',
#                            'lower_ctrl_limit': -10950.0,
#                            'object_name': 'piezo',
#                            'precision': 3,
#                            'shape': [],
#                            'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:3}Mtr.RBV',
#                            'units': 'um',
#                            'upper_ctrl_limit': 11000.0},
#                'piezo_y_user_setpoint': {'dtype': 'number',
#                                          'lower_ctrl_limit': -10950.0,
#                                          'object_name': 'piezo',
#                                          'precision': 3,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:3}Mtr.VAL',
#                                          'units': 'um',
#                                          'upper_ctrl_limit': 11000.0},
#                'piezo_z': {'dtype': 'number',
#                            'lower_ctrl_limit': -36110.0,
#                            'object_name': 'piezo',
#                            'precision': 3,
#                            'shape': [],
#                            'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:6}Mtr.RBV',
#                            'units': 'um',
#                            'upper_ctrl_limit': 24210.0},
#                'piezo_z_user_setpoint': {'dtype': 'number',
#                                          'lower_ctrl_limit': -36110.0,
#                                          'object_name': 'piezo',
#                                          'precision': 3,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-ES:2{MCS:1-Ax:6}Mtr.VAL',
#                                          'units': 'um',
#                                          'upper_ctrl_limit': 24210.0},
#                'prs': {'dtype': 'number',
#                        'lower_ctrl_limit': -269.0,
#                        'object_name': 'prs',
#                        'precision': 5,
#                        'shape': [],
#                        'source': 'PV:XF:12IDC-OP:2{HEX:PRS-Ax:Rot}Mtr.RBV',
#                        'units': 'deg',
#                        'upper_ctrl_limit': 181.0},
#                'prs_user_setpoint': {'dtype': 'number',
#                                      'lower_ctrl_limit': -269.0,
#                                      'object_name': 'prs',
#                                      'precision': 5,
#                                      'shape': [],
#                                      'source': 'PV:XF:12IDC-OP:2{HEX:PRS-Ax:Rot}Mtr.VAL',
#                                      'units': 'deg',
#                                      'upper_ctrl_limit': 181.0},
#                'ring_current': {'dtype': 'number',
#                                 'lower_ctrl_limit': 0.0,
#                                 'object_name': 'ring_current',
#                                 'precision': 3,
#                                 'shape': [],
#                                 'source': 'PV:SR:C03-BI{DCCT:1}I:Real-I',
#                                 'units': 'mA',
#                                 'upper_ctrl_limit': 0.0},
#                'stage_ch': {'dtype': 'number',
#                             'lower_ctrl_limit': -90.0,
#                             'object_name': 'stage',
#                             'precision': 5,
#                             'shape': [],
#                             'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:chi}Mtr.RBV',
#                             'units': 'deg',
#                             'upper_ctrl_limit': 90.0},
#                'stage_ch_user_setpoint': {'dtype': 'number',
#                                           'lower_ctrl_limit': -90.0,
#                                           'object_name': 'stage',
#                                           'precision': 5,
#                                           'shape': [],
#                                           'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:chi}Mtr.VAL',
#                                           'units': 'deg',
#                                           'upper_ctrl_limit': 90.0},
#                'stage_ph': {'dtype': 'number',
#                             'lower_ctrl_limit': -180.0,
#                             'object_name': 'stage',
#                             'precision': 5,
#                             'shape': [],
#                             'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:phi}Mtr.RBV',
#                             'units': 'deg',
#                             'upper_ctrl_limit': 90.0},
#                'stage_ph_user_setpoint': {'dtype': 'number',
#                                           'lower_ctrl_limit': -180.0,
#                                           'object_name': 'stage',
#                                           'precision': 5,
#                                           'shape': [],
#                                           'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:phi}Mtr.VAL',
#                                           'units': 'deg',
#                                           'upper_ctrl_limit': 90.0},
#                'stage_th': {'dtype': 'number',
#                             'lower_ctrl_limit': -90.0,
#                             'object_name': 'stage',
#                             'precision': 5,
#                             'shape': [],
#                             'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:theta}Mtr.RBV',
#                             'units': 'deg',
#                             'upper_ctrl_limit': 90.0},
#                'stage_th_user_setpoint': {'dtype': 'number',
#                                           'lower_ctrl_limit': -90.0,
#                                           'object_name': 'stage',
#                                           'precision': 5,
#                                           'shape': [],
#                                           'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:theta}Mtr.VAL',
#                                           'units': 'deg',
#                                           'upper_ctrl_limit': 90.0},
#                'stage_x': {'dtype': 'number',
#                            'lower_ctrl_limit': -33.0,
#                            'object_name': 'stage',
#                            'precision': 5,
#                            'shape': [],
#                            'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:X}Mtr.RBV',
#                            'units': 'mm',
#                            'upper_ctrl_limit': 33.0},
#                'stage_x_user_setpoint': {'dtype': 'number',
#                                          'lower_ctrl_limit': -33.0,
#                                          'object_name': 'stage',
#                                          'precision': 5,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:X}Mtr.VAL',
#                                          'units': 'mm',
#                                          'upper_ctrl_limit': 33.0},
#                'stage_y': {'dtype': 'number',
#                            'lower_ctrl_limit': -33.0,
#                            'object_name': 'stage',
#                            'precision': 5,
#                            'shape': [],
#                            'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Y}Mtr.RBV',
#                            'units': 'mm',
#                            'upper_ctrl_limit': 33.0},
#                'stage_y_user_setpoint': {'dtype': 'number',
#                                          'lower_ctrl_limit': -33.0,
#                                          'object_name': 'stage',
#                                          'precision': 5,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Y}Mtr.VAL',
#                                          'units': 'mm',
#                                          'upper_ctrl_limit': 33.0},
#                'stage_z': {'dtype': 'number',
#                            'lower_ctrl_limit': -33.0,
#                            'object_name': 'stage',
#                            'precision': 5,
#                            'shape': [],
#                            'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Z}Mtr.RBV',
#                            'units': 'mm',
#                            'upper_ctrl_limit': 33.0},
#                'stage_z_user_setpoint': {'dtype': 'number',
#                                          'lower_ctrl_limit': -33.0,
#                                          'object_name': 'stage',
#                                          'precision': 5,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-OP:2{HEX:Stg-Ax:Z}Mtr.VAL',
#                                          'units': 'mm',
#                                          'upper_ctrl_limit': 33.0}},
#  'hints': {'detector_saxs_pos': {'fields': ['detector_saxs_pos_x',
#                                             'detector_saxs_pos_y',
#                                             'detector_saxs_pos_z']},
#            'energy': {'fields': ['energy_energy',
#                                  'energy_bragg',
#                                  'energy_ivugap',
#                                  'energy_harmonic']},
#            'piezo': {'fields': ['piezo_x',
#                                 'piezo_y',
#                                 'piezo_z',
#                                 'piezo_ch',
#                                 'piezo_th']},
#            'prs': {'fields': ['prs']},
#            'ring_current': {'fields': ['ring_current']},
#            'stage': {'fields': ['stage_x',
#                                 'stage_y',
#                                 'stage_z',
#                                 'stage_th',
#                                 'stage_ph',
#                                 'stage_ch']}},
#  'name': 'baseline',
#  'object_keys': {'detector_saxs_pos': ['detector_saxs_pos_x',
#                                        'detector_saxs_pos_x_user_setpoint',
#                                        'detector_saxs_pos_y',
#                                        'detector_saxs_pos_y_user_setpoint',
#                                        'detector_saxs_pos_z',
#                                        'detector_saxs_pos_z_user_setpoint'],
#                  'energy': ['energy_energy',
#                             'energy_energy_setpoint',
#                             'energy_bragg',
#                             'energy_ivugap',
#                             'energy_harmonic'],
#                  'piezo': ['piezo_x',
#                            'piezo_x_user_setpoint',
#                            'piezo_y',
#                            'piezo_y_user_setpoint',
#                            'piezo_z',
#                            'piezo_z_user_setpoint',
#                            'piezo_ch',
#                            'piezo_ch_user_setpoint',
#                            'piezo_th',
#                            'piezo_th_user_setpoint'],
#                  'prs': ['prs', 'prs_user_setpoint'],
#                  'ring_current': ['ring_current'],
#                  'stage': ['stage_x',
#                            'stage_x_user_setpoint',
#                            'stage_y',
#                            'stage_y_user_setpoint',
#                            'stage_z',
#                            'stage_z_user_setpoint',
#                            'stage_th',
#                            'stage_th_user_setpoint',
#                            'stage_ph',
#                            'stage_ph_user_setpoint',
#                            'stage_ch',
#                            'stage_ch_user_setpoint']},
#  'run_start': 'c834dd6a-91a8-4727-b534-f45ed6acf191',
#  'time': 1731627147.1207337,
#  'uid': 'f789a484-256d-4bca-9d1f-bc792a17e1fc'})),
#  ('event_page',
#   EventPage({'data': {'detector_saxs_pos_x': [-2.9441],
#           'detector_saxs_pos_x_user_setpoint': [-2.77],
#           'detector_saxs_pos_y': [-20.0003],
#           'detector_saxs_pos_y_user_setpoint': [-20.0],
#           'detector_saxs_pos_z': [3000.000512],
#           'detector_saxs_pos_z_user_setpoint': [3000.0000000000005],
#           'energy_bragg': [7.067861757002976],
#           'energy_energy': [16099.99500544827],
#           'energy_energy_setpoint': [16100],
#           'energy_harmonic': [13],
#           'energy_ivugap': [6781.59],
#           'piezo_ch': [7.350293],
#           'piezo_ch_user_setpoint': [7.6000000000000005],
#           'piezo_th': [1.037593],
#           'piezo_th_user_setpoint': [0.396045],
#           'piezo_x': [0.01900000000023283],
#           'piezo_x_user_setpoint': [0.0],
#           'piezo_y': [25.995],
#           'piezo_y_user_setpoint': [0.0],
#           'piezo_z': [-2394.743],
#           'piezo_z_user_setpoint': [0.0],
#           'prs': [-3.0],
#           'prs_user_setpoint': [-3.0],
#           'ring_current': [400.17440319156856],
#           'stage_ch': [-0.001],
#           'stage_ch_user_setpoint': [-0.001],
#           'stage_ph': [-5.0],
#           'stage_ph_user_setpoint': [-5.0],
#           'stage_th': [0.0],
#           'stage_th_user_setpoint': [0.0],
#           'stage_x': [30.5],
#           'stage_x_user_setpoint': [30.5],
#           'stage_y': [2.2],
#           'stage_y_user_setpoint': [2.2],
#           'stage_z': [4.995],
#           'stage_z_user_setpoint': [4.995]},
#  'descriptor': 'f789a484-256d-4bca-9d1f-bc792a17e1fc',
#  'filled': {},
#  'seq_num': [1],
#  'time': [1731627147.1933117],
#  'timestamps': {'detector_saxs_pos_x': [1731627146.18537],
#                 'detector_saxs_pos_x_user_setpoint': [1731515584.466179],
#                 'detector_saxs_pos_y': [1731627146.190322],
#                 'detector_saxs_pos_y_user_setpoint': [1731515576.068849],
#                 'detector_saxs_pos_z': [1731596488.503149],
#                 'detector_saxs_pos_z_user_setpoint': [1731595773.663947],
#                 'energy_bragg': [1731515585.943449],
#                 'energy_energy': [1731515586.489936],
#                 'energy_energy_setpoint': [1731515586.4899561],
#                 'energy_harmonic': [1731594129.2485778],
#                 'energy_ivugap': [1731627146.807101],
#                 'piezo_ch': [1731627146.30515],
#                 'piezo_ch_user_setpoint': [1731515585.064198],
#                 'piezo_th': [1731627146.280529],
#                 'piezo_th_user_setpoint': [1731515586.11181],
#                 'piezo_x': [1731627146.269118],
#                 'piezo_x_user_setpoint': [1731602707.626181],
#                 'piezo_y': [1731627146.294548],
#                 'piezo_y_user_setpoint': [1731599955.169367],
#                 'piezo_z': [1731627143.107971],
#                 'piezo_z_user_setpoint': [1731599957.873181],
#                 'prs': [1731624147.52607],
#                 'prs_user_setpoint': [1731515585.142099],
#                 'ring_current': [1731627146.838292],
#                 'stage_ch': [1731626869.071743],
#                 'stage_ch_user_setpoint': [1731626872.804338],
#                 'stage_ph': [1731626369.518718],
#                 'stage_ph_user_setpoint': [1731626872.802228],
#                 'stage_th': [1731626703.377803],
# ...
#                                                                            'upper_ctrl_limit': 0.0},
#                                               'pil900KW_stats1_hist_min': {'dtype': 'number',
#                                                                            'lower_ctrl_limit': 0.0,
#                                                                            'precision': 0,
#                                                                            'shape': [],
#                                                                            'source': 'PV:XF:12IDC-ES:2{Det:900KW}Stats1:HistMin_RBV',
#                                                                            'units': '',
#                                                                            'upper_ctrl_limit': 0.0},
#                                               'pil900KW_stats1_hist_size': {'dtype': 'integer',
#                                                                             'lower_ctrl_limit': 0,
#                                                                             'shape': [],
#                                                                             'source': 'PV:XF:12IDC-ES:2{Det:900KW}Stats1:HistSize_RBV',
#                                                                             'units': '',
#                                                                             'upper_ctrl_limit': 0},
#                                               'pil900KW_stats1_ts_num_points': {'dtype': 'integer',
#                                                                                 'lower_ctrl_limit': 1,
#                                                                                 'shape': [],
#                                                                                 'source': 'PV:XF:12IDC-ES:2{Det:900KW}Stats1:TS:TSNumPoints',
#                                                                                 'units': '',
#                                                                                 'upper_ctrl_limit': 100000000}},
#                                 'timestamps': {'pil900KW_cam_acquire_period': 1731626953.050621,
#                                                'pil900KW_cam_acquire_time': 1731626953.03936,
#                                                'pil900KW_cam_image_mode': 1731431784.127248,
#                                                'pil900KW_cam_manufacturer': 1731431784.127027,
#                                                'pil900KW_cam_model': 1731431784.127074,
#                                                'pil900KW_cam_num_exposures': 1731431784.127614,
#                                                'pil900KW_cam_num_images': 1731431784.127604,
#                                                'pil900KW_cam_trigger_mode': 1731431784.127287,
#                                                'pil900KW_stats1_bgd_width': 1731431784.126868,
#                                                'pil900KW_stats1_centroid_threshold': 1731431784.126502,
#                                                'pil900KW_stats1_compute_centroid': 1731431784.125715,
#                                                'pil900KW_stats1_compute_histogram': 1731431784.125915,
#                                                'pil900KW_stats1_compute_profiles': 1731431784.125805,
#                                                'pil900KW_stats1_compute_statistics': 1731431784.125615,
#                                                'pil900KW_stats1_hist_max': 1731431784.126668,
#                                                'pil900KW_stats1_hist_min': 1731431784.12659,
#                                                'pil900KW_stats1_hist_size': 1731431784.127024,
#                                                'pil900KW_stats1_ts_num_points': 1731431784.091718}}},
#  'data_keys': {'pil900KW_cam_file_number': {'dtype': 'integer',
#                                             'lower_ctrl_limit': 0,
#                                             'object_name': 'pil900KW',
#                                             'shape': [],
#                                             'source': 'PV:XF:12IDC-ES:2{Det:900KW}cam1:FileNumber_RBV',
#                                             'units': '',
#                                             'upper_ctrl_limit': 0},
#                'pil900KW_image': {'dtype': 'array',
#                                   'dtype_str': '<i4',
#                                   'external': 'FILESTORE:',
#                                   'object_name': 'pil900KW',
#                                   'shape': [1, 619, 1475],
#                                   'source': 'PV:XF:12IDC-ES:2{Det:900KW}'},
#                'pil900KW_stats1_total': {'dtype': 'number',
#                                          'lower_ctrl_limit': 0.0,
#                                          'object_name': 'pil900KW',
#                                          'precision': 0,
#                                          'shape': [],
#                                          'source': 'PV:XF:12IDC-ES:2{Det:900KW}Stats1:Total_RBV',
#                                          'units': '',
#                                          'upper_ctrl_limit': 0.0}},
#  'hints': {'pil900KW': {'fields': ['pil900KW_stats1_total']}},
#  'name': 'primary',
#  'object_keys': {'pil900KW': ['pil900KW_cam_file_number',
#                               'pil900KW_image',
#                               'pil900KW_stats1_total']},
#  'run_start': 'c834dd6a-91a8-4727-b534-f45ed6acf191',
#  'time': 1731627148.285251,
#  'uid': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9'})),
#  ('resource',
#   Resource({'path_semantics': 'posix',
#  'resource_kwargs': {'filename': 'a101042b-3c29-4c2c-aa93',
#                      'frame_per_point': 1,
#                      'template': '%s%s_%6.6d.tiff'},
#  'resource_path': 'nsls2/data/smi/legacy/results/raw/900KW/2024/11/14',
#  'root': '/',
#  'run_start': 'c834dd6a-91a8-4727-b534-f45ed6acf191',
#  'spec': 'AD_TIFF',
#  'uid': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/0'],
#  'datum_kwargs': {'point_number': [0]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602369],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/0'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [1],
#  'time': [1731627148.6368005],
#  'timestamps': {'pil900KW_cam_file_number': [1731627147.251275],
#                 'pil900KW_image': [1731627147.2037325],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['aeb0633e-7413-4490-bab9-d93cfc0ba1b0']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/1'],
#  'datum_kwargs': {'point_number': [1]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602370],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/1'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [2],
#  'time': [1731627149.6616547],
#  'timestamps': {'pil900KW_cam_file_number': [1731627148.703842],
#                 'pil900KW_image': [1731627148.6560774],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['70020873-e560-46f7-8d85-66760b01063c']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/2'],
#  'datum_kwargs': {'point_number': [2]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602371],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/2'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [3],
#  'time': [1731627150.5723927],
#  'timestamps': {'pil900KW_cam_file_number': [1731627149.721192],
#                 'pil900KW_image': [1731627149.673647],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['b21c9e85-e589-4907-b4d1-cdf6a3eef453']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/3'],
#  'datum_kwargs': {'point_number': [3]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602372],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/3'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [4],
#  'time': [1731627151.5831754],
#  'timestamps': {'pil900KW_cam_file_number': [1731627150.632325],
#                 'pil900KW_image': [1731627150.5849576],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['7f533e70-b2c5-4612-8fdd-e2cb115a6bc7']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/4'],
#  'datum_kwargs': {'point_number': [4]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602373],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/4'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [5],
#  'time': [1731627152.6080754],
#  'timestamps': {'pil900KW_cam_file_number': [1731627151.643928],
#                 'pil900KW_image': [1731627151.5966413],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['621ceab5-5fdf-4718-a6a5-c8a4f0353dfd']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/5'],
#  'datum_kwargs': {'point_number': [5]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602374],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/5'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [6],
#  'time': [1731627153.543097],
#  'timestamps': {'pil900KW_cam_file_number': [1731627152.670564],
#                 'pil900KW_image': [1731627152.6230943],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['f0664598-1cb4-4e8c-859b-23e260827680']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/6'],
#  'datum_kwargs': {'point_number': [6]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602375],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/6'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [7],
#  'time': [1731627154.4447424],
#  'timestamps': {'pil900KW_cam_file_number': [1731627153.603941],
#                 'pil900KW_image': [1731627153.556545],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['3cca138e-6182-4d91-b0cf-d87bf05a5f1c']})),
#  ('datum_page',
#   DatumPage({'datum_id': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/7'],
#  'datum_kwargs': {'point_number': [7]},
#  'resource': 'a0d99a43-07f0-488e-91b1-fd7551c5923a'})),
#  ('event_page',
#   EventPage({'data': {'pil900KW_cam_file_number': [602376],
#           'pil900KW_image': ['a0d99a43-07f0-488e-91b1-fd7551c5923a/7'],
#           'pil900KW_stats1_total': [0.0]},
#  'descriptor': '9e2486a0-6efe-48c0-ad2e-fbf0966672e9',
#  'filled': {'pil900KW_image': [False]},
#  'seq_num': [8],
#  'time': [1731627155.4097037],
#  'timestamps': {'pil900KW_cam_file_number': [1731627154.508366],
#                 'pil900KW_image': [1731627154.461187],
#                 'pil900KW_stats1_total': [1731627148.176757]},
#  'uid': ['5749bedc-9a79-4349-af07-b2cc0395b407']})),
#  ('event_page',
#   EventPage({'data': {'detector_saxs_pos_x': [-2.9442],
#           'detector_saxs_pos_x_user_setpoint': [-2.77],
#           'detector_saxs_pos_y': [-20.0003],
#           'detector_saxs_pos_y_user_setpoint': [-20.0],
#           'detector_saxs_pos_z': [3000.000512],
#           'detector_saxs_pos_z_user_setpoint': [3000.0000000000005],
#           'energy_bragg': [7.067861757002976],
#           'energy_energy': [16099.99500544827],
#           'energy_energy_setpoint': [16100],
#           'energy_harmonic': [13],
#           'energy_ivugap': [6781.575],
#           'piezo_ch': [7.350294],
#           'piezo_ch_user_setpoint': [7.6000000000000005],
#           'piezo_th': [1.037598],
#           'piezo_th_user_setpoint': [0.396045],
#           'piezo_x': [0.020000000000436557],
#           'piezo_x_user_setpoint': [0.0],
#           'piezo_y': [25.995],
#           'piezo_y_user_setpoint': [0.0],
#           'piezo_z': [-2394.743],
#           'piezo_z_user_setpoint': [0.0],
#           'prs': [-3.0],
#           'prs_user_setpoint': [-3.0],
#           'ring_current': [399.78912730420484],
#           'stage_ch': [-0.001],
#           'stage_ch_user_setpoint': [-0.001],
#           'stage_ph': [-5.0],
#           'stage_ph_user_setpoint': [-5.0],
#           'stage_th': [0.0],
#           'stage_th_user_setpoint': [0.0],
#           'stage_x': [30.5],
#           'stage_x_user_setpoint': [30.5],
#           'stage_y': [2.2],
#           'stage_y_user_setpoint': [2.2],
#           'stage_z': [4.995],
#           'stage_z_user_setpoint': [4.995]},
#  'descriptor': 'f789a484-256d-4bca-9d1f-bc792a17e1fc',
#  'filled': {},
#  'seq_num': [2],
#  'time': [1731627189.82208],
#  'timestamps': {'detector_saxs_pos_x': [1731627186.903563],
#                 'detector_saxs_pos_x_user_setpoint': [1731515584.466179],
#                 'detector_saxs_pos_y': [1731627187.947301],
#                 'detector_saxs_pos_y_user_setpoint': [1731515576.068849],
#                 'detector_saxs_pos_z': [1731596488.503149],
#                 'detector_saxs_pos_z_user_setpoint': [1731595773.663947],
#                 'energy_bragg': [1731515585.943449],
#                 'energy_energy': [1731515586.489936],
#                 'energy_energy_setpoint': [1731515586.4899561],
#                 'energy_harmonic': [1731594129.2485778],
#                 'energy_ivugap': [1731627189.332939],
#                 'piezo_ch': [1731627189.222539],
#                 'piezo_ch_user_setpoint': [1731515585.064198],
#                 'piezo_th': [1731627188.12627],
#                 'piezo_th_user_setpoint': [1731515586.11181],
#                 'piezo_x': [1731627189.186566],
#                 'piezo_x_user_setpoint': [1731602707.626181],
#                 'piezo_y': [1731627187.068338],
#                 'piezo_y_user_setpoint': [1731599955.169367],
#                 'piezo_z': [1731627188.171368],
#                 'piezo_z_user_setpoint': [1731599957.873181],
#                 'prs': [1731624147.52607],
#                 'prs_user_setpoint': [1731515585.142099],
#                 'ring_current': [1731627189.631438],
#                 'stage_ch': [1731626869.071743],
#                 'stage_ch_user_setpoint': [1731626872.804338],
#                 'stage_ph': [1731626369.518718],
#                 'stage_ph_user_setpoint': [1731626872.802228],
#                 'stage_th': [1731626703.377803],
#                 'stage_th_user_setpoint': [1731626872.800437],
#                 'stage_x': [1731626872.640172],
#                 'stage_x_user_setpoint': [1731626868.715177],
#                 'stage_y': [1731626290.392629],
#                 'stage_y_user_setpoint': [1731626872.795409],
#                 'stage_z': [1731626703.375609],
#                 'stage_z_user_setpoint': [1731626872.798203]},
#  'uid': ['99149c18-ad11-43ef-94f7-9d04cc54cda5']})),
#  ('stop',
#   Stop({'exit_status': 'abort',
#  'num_events': {'baseline': 2, 'primary': 8},
#  'reason': '',
#  'run_start': 'c834dd6a-91a8-4727-b534-f45ed6acf191',
#  'time': 1731627189.8313913,
#  'uid': '76cd4bd7-7dd2-4370-a067-3ea6bb3bd27d'}))]
