# %%
import os
from pathlib import Path

import dotenv
from tiled.client import from_uri
from tiled.client.register import register, Settings

# os.environ['TILED_SINGLE_USER_API_KEY'] = ""
dotenv.load_dotenv(verbose=True, override=True)
os.getenv('TILED_SINGLE_USER_API_KEY')
c = from_uri("http://10.88.0.3:8000", api_key=os.getenv('TILED_SINGLE_USER_API_KEY'))
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File /usr/local/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File /usr/local/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# ...

# %%
c.create_container('raw')
# Out:
# <Container {}>

# %%
raw_node = c['raw']

# %%
await register(
    raw_node,
    "/data/test_data/",
    overwrite=False,
    
)

# %%
# !echo $PWD
